# %%
# Import the module
import importlib
import IsovizPy as ja
import pandas as pd
import gffutils

# %%
# !hostname
# Out:
# ne1dc4-008.nygenome.org

# %%
# Load data and create the database (note this may take 1-2 minutes)
# gtf_file = '/gpfs/commons/home/kisaev/gencode.v47.basic.annotation.gtf'  
gtf_file = '/gpfs/commons/home/kisaev/gencode.v47.annotation.gtf' 

print(gtf_file)

#db = ja.create_db(gtf_file, "human_v47_comp_anno")
# Out:
# /gpfs/commons/home/kisaev/gencode.v47.annotation.gtf

# %%
# Path to the database file created previously
# db_path = "human_v47_gencode_basic"
db_path = "human_v47_comp_anno"

# Load the database
db = gffutils.FeatureDB(db_path, keep_order=True)

# %%
gene_name = "FGFR2"
gene_name = "IQCF6"
gene_name = "SPAM1"
gene_name = "UBE2I"
gene_name = 'OAS1'

print(f"Looking at isoforms for the gene {gene_name}")

# After making changes to IsovizPy, reload it
importlib.reload(ja)

# Example usage when transcripts_list 
bcl2l1_trans = ["ENST00000677494.1",
"ENST00000456404.6",
"ENST00000678563.1",
"ENST00000676942.1",
"ENST00000420488.6",
"ENST00000439267.2",
"ENST00000307677.5",
"ENST00000376062.6",
"ENST00000677194.1",
"ENST00000434194.2",
"ENST00000450273.2",
"ENST00000376055.9",
"ENST00000422920.2",
"ENST00000676582.1",
"ENST00000678671.1"]

fgfr2_trans = ['ENST00000611527.1', 'ENST00000359354.6', 'ENST00000683035.1',
       'ENST00000369059.5', 'ENST00000457416.7', 'ENST00000356226.8',
       'ENST00000360144.7', 'ENST00000346997.6', 'ENST00000369056.5',
       'ENST00000683211.1', 'ENST00000358487.10', 'ENST00000351936.11',
       'ENST00000682550.1', 'ENST00000684153.1', 'ENST00000369061.8',
       'ENST00000357555.9', 'ENST00000613048.4', 'ENST00000369060.8',
       'ENST00000478859.5', 'ENST00000638709.2', 'ENST00000682772.1']
 
oas1_trans = ['ENST00000553185.2', 'ENST00000675868.2', 'ENST00000681700.1',
       'ENST00000680189.1', 'ENST00000680934.1', 'ENST00000679494.1',
       'ENST00000681228.1', 'ENST00000680659.1', 'ENST00000679987.1',
       'ENST00000202917.10', 'ENST00000679467.1', 'ENST00000445409.7',
       'ENST00000540589.3', 'ENST00000552526.2', 'ENST00000679971.1',
       'ENST00000680455.1', 'ENST00000550689.2', 'ENST00000679841.1',
       'ENST00000550883.2', 'ENST00000553152.2', 'ENST00000452357.7',
       'ENST00000551241.6']

trans = ['ENST00000668964.1', 'ENST00000398780.5', 'ENST00000667863.2',
       'ENST00000647442.1']

trans = ['ENST00000413927.5', 'ENST00000439500.5', 'ENST00000460182.5',
       'ENST00000682466.1', 'ENST00000223028.11', 'ENST00000340011.9',
       'ENST00000402183.3']

trans = ['ENST00000397514.8', 'ENST00000397515.7', 'ENST00000567383.7',
       'ENST00000567074.7', 'ENST00000406620.6', 'ENST00000562470.4',
       'ENST00000355803.9', 'ENST00000325437.10', 'ENST00000403747.7',
       'ENST00000566587.6', 'ENST00000568288.6', 'ENST00000568209.6']

gene_name = "HNRNPK" 
trans = ['ENST00000376263.8', 'ENST00000376281.8', 'ENST00000351839.7',
 'ENST00000360384.9', 'ENST00000457156.6']

# find trans in db to get full version .1..?
gene_name = "GTPBP3" 
trans = ['ENST00000361619.9', 'ENST00000324894.13' ,'ENST00000358792.11',
 'ENST00000600625.5']

gene_name = "CFLAR" 
trans = ['ENST00000443227.5', 'ENST00000341222.10', 'ENST00000341582.10',
 'ENST00000342795.9' ,'ENST00000395148.6', 'ENST00000423241.6',
 'ENST00000440180.5' ,'ENST00000457277.5', 'ENST00000494258.5',
 'ENST00000479953.6']

new_order = trans

new_order = new_order[::-1]
transcript_ids = new_order
# Out:
# Looking at isoforms for the gene OAS1

# %% [markdown]
# ## new stuff

# %%
gene_name = "RABGGTB"
trans = ["ENST00000370826.3",
"ENST00000471759.5",
"ENST00000319942.8",
"ENST00000473406.5",
"ENST00000470201.5",
"ENST00000491266.5",
"ENST00000496055.5",
"ENST00000461653.5",
"ENST00000467748.1",
"ENST00000497648.1",
"ENST00000459697.1",
"ENST00000485459.5",
"ENST00000462042.5",
"ENST00000489450.1"]

# After making changes to IsovizPy, reload it
importlib.reload(ja)

transcript_ids = ja.fetch_transcripts_for_gene(db, gene_name)

# Step 2: Fetch transcript annotations
transcript_data = ja.fetch_transcripts_and_annotations(
    db,
    transcript_ids
)
    
# Step 3: Determine region boundaries
region_start, region_end = ja.determine_region_boundaries_from_transcripts(transcript_data)

exons = []
for transcript, values in transcript_data.items():
    for exon in values['exons']:
        exons.append((exon[0], exon[1]))

intronic_intervals = ja.get_intervals_not_overlapped_by_exons(
    region_start, 
    region_end, 
    exons
)

# let's append a new isoform "ENSTX" to transcript data containing custom exon and CDS coordinates 
# the attributes are transcript_id: {transcript_id: , 

new_trans = {'ENST00000319942.8_sans_3rd_exon': {'transcript_id': 'ENST00000319942.8',
'transcript_name': 'RABGGTB-201_sans_3rd_exon',
'transcript_type': 'protein_coding',
'chromosome': 'chr1',
'strand': '+',
'exons': [
	(75786256, 75786274),
	(75787497, 75787604),
	(75789952, 75790057),
	(75791285, 75791337),
	(75791461, 75791571),
	(75792181, 75792306),
	(75794084, 75794233),
	(75794510, 75795086),
],
"cds":[
	(75786272, 75786274),
	(75787497, 75787604),
	(75789952, 75790057),
	(75791285, 75791337),
	(75791461, 75791571),
	(75792181, 75792306),
	(75794084, 75794233),
	(75794510, 75794650),
]
}}

transcript_data = {**new_trans, **transcript_data}
trans_order = ["ENST00000370826.3", 
"ENST00000471759.5",
"ENST00000319942.8",
"ENST00000319942.8_sans_3rd_exon",
"ENST00000473406.5",
"ENST00000470201.5",
"ENST00000491266.5",
"ENST00000496055.5",
"ENST00000461653.5",
"ENST00000467748.1",
"ENST00000497648.1",
"ENST00000459697.1",
"ENST00000485459.5",
"ENST00000462042.5",
"ENST00000489450.1"]

trans_order = trans_order[::-1]

# Step 4: Plot isoforms
height=4.2

ja.plot_isoforms(
    db, 
    transcript_data, 
    region_start-100, 
    region_end+100, 
    transcript_order=trans_order, 
    base_width=10, 
    trans_height=0.1, 
    #fixed_height=True, 
    #fixed_height_value=height,
    introns_list=intronic_intervals,
    plot_shared_intron_lines=False,
    compression_factor=0.1,
    plot_introns_as_blocks=True,
    num_ticks=3,
    trans_label=10)
# Out:
# (dynamic_height 3.5
# Plot saved to RABGGTB_isoforms_plot_20250703_compression_0.1.pdf!

# %%
gene_name = "CCND1"
trans = ["ENST00000227507.3",
"ENST00000539241.1",
"ENST00000535993.1",
"ENST00000545484.1",
"ENST00000536559.1",
"ENST00000542367.1"]

# After making changes to IsovizPy, reload it
importlib.reload(ja)

transcript_ids = ja.fetch_transcripts_for_gene(db, gene_name)

# Step 2: Fetch transcript annotations
transcript_data = ja.fetch_transcripts_and_annotations(
    db,
    transcript_ids
)
    
# Step 3: Determine region boundaries
region_start, region_end = ja.determine_region_boundaries_from_transcripts(transcript_data)

exons = []
for transcript, values in transcript_data.items():
    for exon in values['exons']:
        exons.append((exon[0], exon[1]))

intronic_intervals = ja.get_intervals_not_overlapped_by_exons(
    region_start, 
    region_end, 
    exons
)

# let's append a new isoform "ENSTX" to transcript data containing custom exon and CDS coordinates 
# the attributes are transcript_id: {transcript_id: , 

new_trans = {'ENST00000227507.3_sans_2nd_exon': {'transcript_id': 'ENST00000227507.3',
'transcript_name': 'CCND1-201_sans_2nd_exon',
'transcript_type': 'protein_coding',
'chromosome': 'chr11',
'strand': '+',
'exons': [
	(69641156,69641511),
	(69643832,69643991),
	(69647994,69648142),
	(69651118,69654474),
],
"cds":[
	(69641314, 69641511),
	(69643832, 69643991),
	(69647994, 69648142),
	(69651118, 69651282),
]
}}

transcript_data = {**new_trans, **transcript_data}
trans_order = ["ENST00000227507.3",
               "ENST00000227507.3_sans_2nd_exon",
"ENST00000539241.1",
"ENST00000535993.1",
"ENST00000545484.1",
"ENST00000536559.1",
"ENST00000542367.1"]

trans_order = trans_order[::-1]

# Step 4: Plot isoforms
height=4.2

ja.plot_isoforms(
    db, 
    transcript_data, 
    region_start-100, 
    region_end+100, 
    transcript_order=trans_order, 
    base_width=10, 
    trans_height=0.1, 
    #fixed_height=True, 
    #fixed_height_value=height,
    introns_list=intronic_intervals,
    plot_shared_intron_lines=False,
    compression_factor=0.1,
    plot_introns_as_blocks=True,
    num_ticks=3,
    trans_label=10)
# Out:
# (dynamic_height 2.7
# Plot saved to CCND1_isoforms_plot_20250703_compression_0.1.pdf!

# %%
gene_name = "TAF5"

# After making changes to IsovizPy, reload it
importlib.reload(ja)

transcript_ids = ja.fetch_transcripts_for_gene(db, gene_name)

# Step 2: Fetch transcript annotations
transcript_data = ja.fetch_transcripts_and_annotations(
    db,
    transcript_ids
)

transcript_data
# Out:
# {'ENST00000369839.4': {'transcript_id': 'ENST00000369839.4',
#   'transcript_name': 'TAF5-201',
#   'transcript_type': 'protein_coding',
#   'chromosome': 'chr10',
#   'exons': [(103367976, 103368548),
#    (103373358, 103373595),
#    (103378235, 103378550),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103381841),
#    (103383238, 103383367),
#    (103385326, 103385490),
#    (103387175, 103387352),
#    (103387521, 103387698),
#    (103388006, 103389065)],
#   'cds': [(103367990, 103368548),
#    (103373358, 103373595),
#    (103378235, 103378550),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103381841),
#    (103383238, 103383367),
#    (103385326, 103385490),
#    (103387175, 103387352),
#    (103387521, 103387698),
#    (103388006, 103388220)],
#   'strand': '+'},
#  'ENST00000684872.1': {'transcript_id': 'ENST00000684872.1',
#   'transcript_name': 'TAF5-202',
#   'transcript_type': 'nonsense_mediated_decay',
#   'chromosome': 'chr10',
#   'exons': [(103367990, 103368567),
#    (103373358, 103373595),
#    (103378235, 103378543)],
#   'cds': [(103367990, 103368567), (103373358, 103373439)],
#   'strand': '+'},
#  'ENST00000686612.1': {'transcript_id': 'ENST00000686612.1',
#   'transcript_name': 'TAF5-203',
#   'transcript_type': 'retained_intron',
#   'chromosome': 'chr10',
#   'exons': [(103386941, 103387352), (103387521, 103389026)],
#   'cds': [],
#   'strand': '+'},
#  'ENST00000687501.1': {'transcript_id': 'ENST00000687501.1',
#   'transcript_name': 'TAF5-204',
#   'transcript_type': 'retained_intron',
#   'chromosome': 'chr10',
#   'exons': [(103367990, 103368548),
#    (103373358, 103373595),
#    (103378235, 103378550),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103383367),
#    (103385326, 103385490),
#    (103387175, 103387352),
#    (103387521, 103387698),
#    (103388006, 103389040)],
#   'cds': [],
#   'strand': '+'},
#  'ENST00000687830.1': {'transcript_id': 'ENST00000687830.1',
#   'transcript_name': 'TAF5-205',
#   'transcript_type': 'retained_intron',
#   'chromosome': 'chr10',
#   'exons': [(103367981, 103368548), (103373358, 103375103)],
#   'cds': [],
#   'strand': '+'},
#  'ENST00000690052.1': {'transcript_id': 'ENST00000690052.1',
#   'transcript_name': 'TAF5-206',
#   'transcript_type': 'nonsense_mediated_decay',
#   'chromosome': 'chr10',
#   'exons': [(103367966, 103368548),
#    (103373358, 103373595),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103381841),
#    (103383238, 103383367),
#    (103385326, 103385490),
#    (103387175, 103387352),
#    (103387521, 103387698),
#    (103388006, 103389045)],
#   'cds': [(103367990, 103368548),
#    (103373358, 103373595),
#    (103379608, 103379623)],
#   'strand': '+'},
#  'ENST00000690667.1': {'transcript_id': 'ENST00000690667.1',
#   'transcript_name': 'TAF5-207',
#   'transcript_type': 'retained_intron',
#   'chromosome': 'chr10',
#   'exons': [(103367990, 103368548),
#    (103373358, 103373595),
#    (103378235, 103378550),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103381841),
#    (103385326, 103385618)],
#   'cds': [],
#   'strand': '+'},
#  'ENST00000692195.1': {'transcript_id': 'ENST00000692195.1',
#   'transcript_name': 'TAF5-208',
#   'transcript_type': 'protein_coding',
#   'chromosome': 'chr10',
#   'exons': [(103367972, 103368548),
#    (103373358, 103373595),
#    (103378235, 103378550),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103381841),
#    (103383238, 103383367),
#    (103387175, 103387352),
#    (103387521, 103387698),
#    (103388006, 103388998)],
#   'cds': [(103367990, 103368548),
#    (103373358, 103373595),
#    (103378235, 103378550),
#    (103379608, 103379771),
#    (103379884, 103380019),
#    (103381721, 103381841),
#    (103383238, 103383367),
#    (103387175, 103387352),
#    (103387521, 103387698),
#    (103388006, 103388220)],
#   'strand': '+'},
#  'ENST00000692471.1': {'transcript_id': 'ENST00000692471.1',
#   'transcript_name': 'TAF5-209',
#   'transcript_type': 'retained_intron',
#   'chromosome': 'chr10',
#   'exons': [(103385370, 103385490), (103387175, 103389030)],
#   'cds': [],
#   'strand': '+'},
#  'ENST00000693184.1': {'transcript_id': 'ENST00000693184.1',
#   'transcript_name': 'TAF5-210',
#   'transcript_type': 'retained_intron',
#   'chromosome': 'chr10',
#   'exons': [(103387116, 103387352),
#    (103387521, 103387698),
#    (103388006, 103389026)],
#   'cds': [],
#   'strand': '+'}}

# %%
# Step 3: Determine region boundaries
region_start, region_end = ja.determine_region_boundaries_from_transcripts(transcript_data)
region_start, region_end
# Out:
# (103367966, 103389065)

# %%
exons = []
for transcript, values in transcript_data.items():
    for exon in values['exons']:
        exons.append((exon[0], exon[1]))

intronic_intervals = ja.get_intervals_not_overlapped_by_exons(
    region_start, 
    region_end, 
    exons
)
# Out:
# [(103368568, 103373357),
#  (103375104, 103378234),
#  (103378551, 103379607),
#  (103379772, 103379883),
#  (103380020, 103381720),
#  (103383368, 103385325),
#  (103385619, 103386940)]

# %%
transcript_order = list(transcript_data.keys())
transcript_order
# Out:
# ['ENST00000369839.4',
#  'ENST00000684872.1',
#  'ENST00000686612.1',
#  'ENST00000687501.1',
#  'ENST00000687830.1',
#  'ENST00000690052.1',
#  'ENST00000690667.1',
#  'ENST00000692195.1',
#  'ENST00000692471.1',
#  'ENST00000693184.1']

# %%
# Step 4: Plot isoforms
height=4.2

ja.plot_isoforms(
    db, 
    transcript_data, 
    region_start-100, 
    region_end+100, 
    base_width=10, 
    trans_height=0.1, 
    transcript_order=transcript_order, 
    #fixed_height=True, 
    #fixed_height_value=height,
    introns_list=intronic_intervals,
    plot_shared_intron_lines=False,
    compression_factor=0.1,
    plot_introns_as_blocks=True,
    num_ticks=3,
    trans_label=10)
# Out:
# (dynamic_height 3.0
# Plot saved to TAF5_isoforms_plot_20250703_compression_0.1.pdf!

# %%
transcript_order
# Out:
# ['ENST00000369839.4_sans_exon_8',
#  'ENST00000369839.4',
#  'ENST00000684872.1',
#  'ENST00000686612.1',
#  'ENST00000687501.1',
#  'ENST00000687830.1',
#  'ENST00000690052.1',
#  'ENST00000690667.1',
#  'ENST00000692195.1',
#  'ENST00000692471.1',
#  'ENST00000693184.1']

# %%
gene_name = "TAF5"

# After making changes to IsovizPy, reload it
importlib.reload(ja)

transcript_ids = ja.fetch_transcripts_for_gene(db, gene_name)

# Step 2: Fetch transcript annotations
transcript_data = ja.fetch_transcripts_and_annotations(
    db,
    transcript_ids
)
    
# Step 3: Determine region boundaries
region_start, region_end = ja.determine_region_boundaries_from_transcripts(transcript_data)

exons = []
for transcript, values in transcript_data.items():
    for exon in values['exons']:
        exons.append((exon[0], exon[1]))

intronic_intervals = ja.get_intervals_not_overlapped_by_exons(
    region_start, 
    region_end, 
    exons
)

transcript_order = list(transcript_data.keys())

# Step 4: Plot isoforms
height=4.2

ja.plot_isoforms(
    db, 
    transcript_data, 
    region_start-500, 
    region_end+500, 
    base_width=12, 
    trans_height=0.2, 
    #fixed_height=True, 
    #fixed_height_value=height,
    transcript_order=transcript_order, 
    introns_list=intronic_intervals,
    plot_shared_intron_lines=False,
    compression_factor=0.7,
    plot_introns_as_blocks=True,
    num_ticks=3,
    trans_label=10)
# Out:
# (dynamic_height 4.0
# Plot saved to TAF5_isoforms_plot_20250703_compression_0.7.pdf!

# %%
selected_transcripts = ['ENST00000369839.4', 'ENST00000692195.1']
transcript_data = {k: v for k, v in transcript_data.items() if k in selected_transcripts}
transcript_order = selected_transcripts  # or list(transcript_data.keys()) to be safe
exons = []
for transcript, values in transcript_data.items():
    exons.extend(values['exons'])

region_start, region_end = ja.determine_region_boundaries_from_transcripts(transcript_data)

intronic_intervals = ja.get_intervals_not_overlapped_by_exons(
    region_start,
    region_end,
    exons
)
ja.plot_isoforms(
    db, 
    transcript_data, 
    region_start - 500, 
    region_end + 500, 
    base_width=12, 
    trans_height=0.2, 
    transcript_order=transcript_order, 
    introns_list=intronic_intervals,
    plot_shared_intron_lines=True,
    compression_factor=1,
    plot_introns_as_blocks=False,
    num_ticks=3,
    trans_label=10
)
# Out:
# (dynamic_height 2.4
# Plot saved to TAF5_isoforms_plot_20250703_compression_1.pdf!
