# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import glob
import os
from matplotlib.ticker import ScalarFormatter

# %%
model_outputs = "/gpfs/commons/groups/knowles_lab/Karin/Leaflet-analysis-WD/Simulations/2025/manuscript_sim_analysis/2025-02-22/"

# Check the specific pattern
run_summary_files = glob.glob(os.path.join(model_outputs, "*", "*run_summary.csv"))
 
# Read in the run summary files
run_summary = pd.concat([pd.read_csv(f) for f in run_summary_files])

# Split into K=2 and K=9 since seperate types of analysis
run_summary_K2 = run_summary[run_summary["K"] == 2]
run_summary_K9 = run_summary[run_summary["K"] == 9]

# Let's have another calumn likelihood if input_conc is a number then beta-binom and if "inf" then binomial
run_summary_K2["likelihood"] = np.where(run_summary_K2["input_conc"] == np.inf, "binomial", "beta-binomial")
run_summary_K9["likelihood"] = np.where(run_summary_K9["input_conc"] == np.inf, "binomial", "beta-binomial")
# Out:
# /scratch/ipykernel_2813302/726644452.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_summary_K2["likelihood"] = np.where(run_summary_K2["input_conc"] == np.inf, "binomial", "beta-binomial")
# /scratch/ipykernel_2813302/726644452.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   run_summary_K9["likelihood"] = np.where(run_summary_K9["input_conc"] == np.inf, "binomial", "beta-binomial")

# %%
# find *classification_metrics.csv files and read them in while adding in which "run_X" subfolder they came from
classification_metrics_files = glob.glob(os.path.join(model_outputs, "*", "*classification_metrics.csv"))
# Read in the classification metrics files and add in the run number
classification_metrics = pd.concat([pd.read_csv(f).assign(run=f.split("/")[11]) for f in classification_metrics_files])
# make param_id column of just the run number "run_x"
classification_metrics["param_id"] = classification_metrics["run"].str.split("_").str[1]
# Make param_id an integer64
classification_metrics["param_id"] = classification_metrics["param_id"].astype("int64")
run_summary_K2 = run_summary_K2.merge(classification_metrics, on="param_id")

# %% [markdown]
# ### Compare model performance (which has the lowest -ELBO values...) across different configurations of parameters

# %%
plt.figure(figsize=(12, 6))
g = sns.FacetGrid(run_summary_K2, 
                  col="likelihood",
                  hue="junc_specific_prior",
                  sharey=False)

# Use line plot to show trends more clearly
g.map(sns.lineplot, "proportion_negative", "best_elbo")

# Format y-axis labels
for ax in g.axes.flat:
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    ax.yaxis.set_major_formatter(formatter)

g.add_legend()
g.set_axis_labels("Proportion Negative Labels", "-ELBO")

g.fig.suptitle('Model Performance for K=2', y=1.05)  # y=1.02 raises it slightly above the plots
# Out:
# Text(0.5, 1.05, 'Model Performance for K=2')

# %%
plt.figure(figsize=(12, 6))
g = sns.FacetGrid(run_summary_K2, 
                  col="likelihood",
                  hue="junc_specific_prior",
                  sharey=False)

# Use line plot to show trends more clearly
g.map(sns.lineplot, "lr", "best_elbo")

# Format y-axis labels
for ax in g.axes.flat:
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    ax.yaxis.set_major_formatter(formatter)

g.add_legend()
g.set_axis_labels("Learning Rate", "-ELBO")

# Add title
g.fig.suptitle('Model Performance for K=2', y=1.05)  # y=1.02 raises it slightly above the plots
# Out:
# Text(0.5, 1.05, 'Model Performance for K=2')

# %%
run_summary_K2[run_summary_K2["likelihood"] == "binomial"].sort_values(by=["junc_specific_prior", "best_elbo"])
# Out:
#     param_id  K  junc_specific_prior     best_elbo  input_conc  num_epochs  \
# 26       177  2                False  2.660305e+07         inf         300
# 7        168  2                False  2.709291e+07         inf         300
# 35       178  2                False  2.716152e+07         inf         300
# 25       188  2                False  2.721787e+07         inf         300
# 62       170  2                False  2.727365e+07         inf         300
# 80       163  2                False  2.727792e+07         inf         300
# 5        179  2                False  2.730060e+07         inf         300
# 30       171  2                False  2.750563e+07         inf         300
# 61       181  2                False  2.752931e+07         inf         300
# 29       182  2                False  2.754381e+07         inf         300
# 42       172  2                False  2.755452e+07         inf         300
# 53       187  2                False  2.756712e+07         inf         300
# 12       162  2                False  2.763843e+07         inf         300
# 90       164  2                False  2.764815e+07         inf         300
# 11       173  2                False  2.765037e+07         inf         300
# 86       186  2                False  2.774985e+07         inf         300
# 89       175  2                False  2.824185e+07         inf         300
# 54       176  2                False  2.831698e+07         inf         300
# 92       180  2                False  2.836608e+07         inf         300
# 56       165  2                False  2.841190e+07         inf         300
# 75       169  2                False  2.952385e+07         inf         300
# 10       184  2                False  3.039888e+07         inf         300
# 79       185  2                False  3.225284e+07         inf         300
# 52       116  2                 True  2.728288e+07         inf         300
# 84       126  2                 True  2.937665e+07         inf         300
# 23       128  2                 True  2.951361e+07         inf         300
# 57       132  2                 True  3.003456e+07         inf         300
# 27       133  2                 True  3.051129e+07         inf         300
# 82       130  2                 True  3.052958e+07         inf         300
# 28       122  2                 True  3.101610e+07         inf         300
# 33       118  2                 True  3.195190e+07         inf         300
# 77       125  2                 True  3.263369e+07         inf         300
# 24       117  2                 True  3.450842e+07         inf         300
# 51       127  2                 True  3.583530e+07         inf         300
# 37       134  2                 True  3.724851e+07         inf         300
# 32       129  2                 True  3.879424e+07         inf         300
# 59       121  2                 True  4.952422e+07         inf         300
# 39       123  2                 True  5.011344e+07         inf         300
# 3        119  2                 True  5.253256e+07         inf         300
# 85       115  2                 True  1.567997e+08         inf         300
# 40       112  2                 True  1.599733e+08         inf         300
# 74       109  2                 True  1.674701e+08         inf         300
# 4        108  2                 True  1.987525e+08         inf         300
# 9        113  2                 True  2.583849e+08         inf         300
# 91       120  2                 True  4.631403e+08         inf         300
# 78       114  2                 True  8.603921e+08         inf         300
# 60       110  2                 True  1.323451e+09         inf         300
#
#     num_inits  cell_type_silhouette  avg_corr  median_corr  ...  \
# 26          5              0.941710  0.509303     0.846015  ...
# 7           5              0.935711  0.141417     0.020522  ...
# 35          5              0.944460  0.999736     0.999768  ...
# 25          5              0.926263  0.371337     0.041785  ...
# 62          5              0.939828  0.205628     0.064574  ...
# 80          5              0.963718  0.997782     0.998086  ...
# 5           5              0.940124  0.583938     0.867514  ...
# 30          5              0.964523  0.664552     0.994279  ...
# 61          5              0.963768  0.632740     0.985338  ...
# 29          5              0.963063  0.585762     0.995465  ...
# 42          5              0.963743  0.999817     0.999884  ...
# 53          5              0.936012  0.782737     0.822777  ...
# 12          5              0.962486  0.606225     0.998524  ...
# 90          5              0.965148  0.333714     0.252959  ...
# 11          5              0.963685  0.448454     0.399129  ...
# 86          5              0.927546  0.268906     0.081141  ...
# 89          5              0.975707  0.999913     0.999921  ...
# 54          5              0.975203  0.599330     0.998810  ...
# 92          5              0.960673  0.991451     0.994632  ...
# 56          5              0.970737  0.600265     0.971504  ...
# 75          5              0.914112  0.321282     0.068152  ...
# 10          5              0.968082  0.524454     0.731808  ...
# 79          5              0.964846  0.593647     0.998738  ...
# 52          5              0.920041  0.721960     0.727797  ...
# 84          5              0.961280  0.977060     0.984487  ...
# 23          5              0.958208  0.989638     0.990899  ...
# 57          5              0.912128  0.939177     0.940160  ...
# 27          5              0.909865  0.913380     0.928588  ...
# 82          5              0.970429  0.991092     0.994740  ...
# 28          5              0.965854  0.949333     0.966046  ...
# 33          5              0.948976  0.986170     0.985272  ...
# 77          5              0.884514  0.853327     0.856500  ...
# 24          5              0.950659  0.994018     0.993494  ...
# 51          5              0.946760  0.985486     0.993277  ...
# 37          5              0.846473  0.955419     0.955156  ...
# 32          5              0.961029  0.980778     0.980855  ...
# 59          5              0.959004  0.992595     0.996314  ...
# 39          5              0.899248  0.924924     0.929460  ...
# 3           5              0.933550  0.987508     0.991653  ...
# 85          5              0.849327  0.660975     0.820355  ...
# 40          5              0.956265  0.843479     0.880945  ...
# 74          5              0.931680  0.940033     0.947131  ...
# 4           5              0.910237  0.679694     0.694787  ...
# 9           5              0.945496  0.963765     0.972643  ...
# 91          5              0.942469  0.991903     0.992308  ...
# 78          5              0.699432  0.403767     0.504440  ...
# 60          5              0.877158  0.489734     0.625461  ...
#
#     spearman_corr_impdfiff  pearson_corr_impdiff  proportion_negative  \
# 26                0.617978              0.999769                 0.85
# 7                 0.620225              0.999788                 0.85
# 35                0.619485              0.999806                 0.85
# 25                0.610696              0.997622                 0.85
# 62                0.619107              0.999823                 0.85
# 80                0.934656              0.999905                 0.50
# 5                 0.619324              0.999773                 0.85
# 30                0.932972              0.999879                 0.50
# 61                0.932187              0.999581                 0.50
# 29                0.931046              0.999684                 0.50
# 42                0.933189              0.999852                 0.50
# 53                0.618805              0.998352                 0.85
# 12                0.933785              0.999898                 0.50
# 90                0.934045              0.999903                 0.50
# 11                0.932621              0.999881                 0.50
# 86                0.614420              0.996665                 0.85
# 89                0.997855              0.999858                 0.15
# 54                0.997867              0.999856                 0.15
# 92                0.928698              0.998520                 0.50
# 56                0.997872              0.999888                 0.15
# 75                0.617680              0.976293                 0.85
# 10                0.995317              0.997861                 0.15
# 79                0.993084              0.994710                 0.15
# 52                0.620618              0.996633                 0.85
# 84                0.928938              0.998093                 0.50
# 23                0.926108              0.997249                 0.50
# 57                0.613715              0.986820                 0.85
# 27                0.613302              0.986033                 0.85
# 82                0.993648              0.997396                 0.15
# 28                0.994991              0.996700                 0.15
# 33                0.929035              0.991687                 0.50
# 77                0.610631              0.950999                 0.85
# 24                0.924455              0.988524                 0.50
# 51                0.919361              0.985586                 0.50
# 37                0.592459              0.885530                 0.85
# 32                0.987046              0.987746                 0.15
# 59                0.984288              0.984024                 0.15
# 39                0.608627              0.973995                 0.85
# 3                 0.907052              0.960544                 0.50
# 85                0.592444              0.911232                 0.85
# 40                0.948138              0.958114                 0.15
# 74                0.908115              0.970629                 0.50
# 4                 0.889314              0.930472                 0.50
# 9                 0.896784              0.904824                 0.15
# 91                0.823693              0.841866                 0.15
# 78                0.510463              0.662170                 0.85
# 60                0.570584              0.686004                 0.50
#
#     pruned_K  likelihood    auc_pr   auc_roc  pearson_corr_es  \
# 26         2    binomial  0.828126  0.958124         0.763931
# 7          2    binomial  0.946898  0.938838         0.999691
# 35         2    binomial  0.940070  0.930734         0.996718
# 25         2    binomial  0.920937  0.983818         0.710420
# 62         2    binomial  0.948580  0.940724         0.999720
# 80         2    binomial  0.977892  0.969620         0.915999
# 5          2    binomial  0.373852  0.651656         0.155406
# 30         2    binomial  0.962037  0.931326         0.999739
# 61         2    binomial  0.960399  0.928005         0.997746
# 29         2    binomial  0.978080  0.963713         0.980759
# 42         2    binomial  0.965038  0.936368         0.999028
# 53         2    binomial  0.943365  0.934488         0.997720
# 12         2    binomial  0.961182  0.930675         0.999838
# 90         2    binomial  0.470648  0.539614         0.031765
# 11         2    binomial  0.532197  0.597105         0.150406
# 86         2    binomial  0.872195  0.971245         0.696765
# 89         2    binomial  0.982321  0.927530         0.999819
# 54         2    binomial  0.987613  0.951053         0.987504
# 92         2    binomial  0.981823  0.973516         0.964561
# 56         2    binomial  0.983162  0.930514         0.999825
# 75         2    binomial  0.953676  0.975779         0.923030
# 10         2    binomial  0.990742  0.963301         0.974961
# 79         2    binomial  0.991087  0.965533         0.967880
# 52         2    binomial  0.942426  0.934354         0.995685
# 84         2    binomial  0.983759  0.974451         0.960009
# 23         2    binomial  0.977696  0.965366         0.972274
# 57         2    binomial  0.858585  0.966746         0.716680
# 27         2    binomial  0.914474  0.969623         0.749723
# 82         2    binomial  0.992270  0.970465         0.973478
# 28         2    binomial  0.990902  0.964365         0.949390
# 33         2    binomial  0.974753  0.956668         0.989717
# 77         2    binomial  0.613334  0.783647         0.467082
# 24         2    binomial  0.976868  0.961172         0.958267
# 51         2    binomial  0.799050  0.804509         0.435700
# 37         2    binomial  0.854693  0.962167         0.679260
# 32         2    binomial  0.989589  0.956292         0.987637
# 59         2    binomial  0.986623  0.943866         0.984024
# 39         2    binomial  0.510502  0.757534         0.344140
# 3          2    binomial  0.974384  0.962712         0.893036
# 85         2    binomial  0.727149  0.837171         0.617457
# 40         2    binomial  0.985767  0.943550         0.954321
# 74         2    binomial  0.972024  0.962599         0.884947
# 4          2    binomial  0.823933  0.780145         0.531238
# 9          2    binomial  0.870578  0.628812         0.238435
# 91         2    binomial  0.988492  0.957234         0.841795
# 78         2    binomial  0.537497  0.711402         0.421275
# 60         2    binomial  0.460502  0.532906         0.017625
#
#    spearman_corr_es      run
# 26         0.539953  run_177
# 7          0.619468  run_168
# 35         0.607320  run_178
# 25         0.545491  run_188
# 62         0.616871  run_170
# 80         0.872119  run_163
# 5          0.138263  run_179
# 30         0.932729  run_171
# 61         0.925680  run_181
# 29         0.914177  run_182
# 42         0.927785  run_172
# 53         0.617975  run_187
# 12         0.932872  run_162
# 90         0.040683  run_164
# 11         0.172376  run_173
# 86         0.524066  run_186
# 89         0.997745  run_175
# 54         0.984420  run_176
# 92         0.904373  run_180
# 56         0.997677  run_165
# 75         0.583280  run_169
# 10         0.969943  run_184
# 79         0.962018  run_185
# 52         0.616906  run_116
# 84         0.904010  run_126
# 23         0.904619  run_128
# 57         0.527572  run_132
# 27         0.530631  run_133
# 82         0.967611  run_130
# 28         0.943815  run_122
# 33         0.919148  run_118
# 77         0.229222  run_125
# 24         0.884777  run_117
# 51         0.408200  run_127
# 37         0.528258  run_134
# 32         0.986838  run_129
# 59         0.984283  run_121
# 39         0.286388  run_123
# 3          0.817154  run_119
# 85         0.301176  run_115
# 40         0.941124  run_112
# 74         0.824705  run_109
# 4          0.351917  run_108
# 9          0.094742  run_113
# 91         0.823235  run_120
# 78         0.135975  run_114
# 60         0.020619  run_110
#
# [47 rows x 24 columns]

# %%
plt.figure(figsize=(12, 6))
g = sns.FacetGrid(run_summary_K9, 
                  col="likelihood",
                  hue="junc_specific_prior",
                  sharey=False)

# Use line plot to show trends more clearly
g.map(sns.lineplot, "proportion_negative", "best_elbo")

# Format y-axis labels
for ax in g.axes.flat:
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    ax.yaxis.set_major_formatter(formatter)

g.add_legend()
g.set_axis_labels("Proportion Negative Labels", "-ELBO")

g.fig.suptitle('Model Performance for K=9', y=1.05)  # y=1.02 raises it slightly above the plots
# Out:
# Text(0.5, 1.05, 'Model Performance for K=9')

# %%
plt.figure(figsize=(12, 6))
g = sns.FacetGrid(run_summary_K9, 
                  col="likelihood",
                  hue="junc_specific_prior",
                  sharey=False)

# Use line plot to show trends more clearly
g.map(sns.lineplot, "lr", "best_elbo")

# Format y-axis labels
for ax in g.axes.flat:
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    ax.yaxis.set_major_formatter(formatter)

g.add_legend()
g.set_axis_labels("Learning Rate", "-ELBO")

# Add title
g.fig.suptitle('Model Performance for K=9', y=1.05)  # y=1.02 raises it slightly above the plots
# Out:
# Text(0.5, 1.05, 'Model Performance for K=9')

# %% [markdown]
# ### Now let's summarize accuracy metrics

# %%
plt.figure(figsize=(10, 6))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))

# Plot for AUC-PR
sns.boxplot(x='likelihood', y='auc_pr', 
           hue='junc_specific_prior',
           data=run_summary_K2, ax=ax1)
ax1.set_title('AUC-PR Distribution by Model Configuration')
ax1.set_ylim(0, 1)

# Plot for AUC-ROC
sns.boxplot(x='likelihood', y='auc_roc',
           hue='junc_specific_prior',
           data=run_summary_K2, ax=ax2)
ax2.set_title('AUC-ROC Distribution by Model Configuration')
ax2.set_ylim(0, 1)

plt.suptitle('Performance Metrics for K=2 Models', y=1.05)
plt.tight_layout()

# %%
# Second figure for Silhouette and Correlation metrics
plt.figure(figsize=(10, 6))
fig2, (ax3, ax4) = plt.subplots(1, 2, figsize=(10, 6))

# Plot for Cell Type Silhouette
sns.boxplot(x='likelihood', y='cell_type_silhouette',
            hue='junc_specific_prior',
            data=run_summary_K2, ax=ax3)
ax3.set_title('Cell Type Silhouette')
ax3.set_ylim(0, 1)

# Plot for Median Correlation
sns.boxplot(x='likelihood', y='median_corr',
            hue='junc_specific_prior',
            data=run_summary_K2, ax=ax4)
ax4.set_title('Median Correlation')
ax4.set_ylim(-1, 1.1)  # Since correlation ranges from -1 to 1

plt.suptitle('Clustering Performance Metrics for K=2 Models', y=1.05)
plt.tight_layout()

# %%
run_summary_K9.sort_values(by="cell_type_silhouette")
# Out:
#     param_id  K  junc_specific_prior     best_elbo   input_conc  num_epochs  \
# 0        143  9                 True  1.048767e+09          inf         300
# 0        141  9                 True  1.094578e+09          inf         300
# 0         33  9                 True  5.519152e+07     1.233005         300
# 0        142  9                 True  1.587293e+09          inf         300
# 0        147  9                 True  2.727944e+08          inf         300
# ..       ... ..                  ...           ...          ...         ...
# 0        203  9                False  2.995468e+07          inf         300
# 0         94  9                False  2.959267e+07  1724.279000         300
# 0        202  9                False  3.041177e+07          inf         300
# 0         93  9                False  2.964510e+07  1578.973500         300
# 0        201  9                False  2.894910e+07          inf         300
#
#     num_inits  cell_type_silhouette  avg_corr  median_corr  min_corr   lr  \
# 0           5             -0.093465  0.151111     0.200013 -0.042572  0.1
# 0           5             -0.033281  0.226167     0.199156  0.162969  0.1
# 0           5             -0.032174  0.043061    -0.031763 -0.312836  0.1
# 0           5             -0.005844  0.243894     0.213983  0.094074  0.1
# 0           5              0.030337  0.367553     0.264718  0.102341  0.5
# ..        ...                   ...       ...          ...       ...  ...
# 0           5              0.900974  0.384114     0.264294 -0.091633  0.5
# 0           5              0.905440  0.342676     0.268005 -0.163290  0.5
# 0           5              0.908071  0.615443     0.944236  0.075312  0.5
# 0           5              0.911091  0.367516     0.289050  0.031284  0.5
# 0           5              0.911095  0.406073     0.630220 -0.172608  0.5
#
#     ELBO_num_particles  num_samples  spearman_corr_impdfiff  \
# 0                   10          500                0.125607
# 0                   10          500                0.071564
# 0                   10          500                0.040382
# 0                   10          500                0.187248
# 0                   10          500                0.266927
# ..                 ...          ...                     ...
# 0                   10          500                0.907194
# 0                   10          500                0.914216
# 0                   10          500                0.903288
# 0                   10          500                0.882897
# 0                   10          500                0.910201
#
#     pearson_corr_impdiff  proportion_negative  pruned_K     likelihood
# 0               0.297678                 0.85         9       binomial
# 0               0.172599                 0.85         9       binomial
# 0               0.014441                 0.85         9  beta-binomial
# 0               0.296766                 0.85         9       binomial
# 0               0.170043                 0.15         9       binomial
# ..                   ...                  ...       ...            ...
# 0               0.900420                 0.15         9       binomial
# 0               0.892211                 0.15         9  beta-binomial
# 0               0.890019                 0.15         9       binomial
# 0               0.892947                 0.15         9  beta-binomial
# 0               0.896035                 0.15         9       binomial
#
# [107 rows x 19 columns]
